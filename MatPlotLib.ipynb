# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[25,16,19,30]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[25,16,19,30]
plt.plot(x,y,linestyle="--",linewidth=3,marker='*',ms=20)
plt.xlabel('x axis-->',fontsize=20,color='blue',fontweight='bold')
plt.ylabel('y axis-->',fontsize=20,color='red',fontweight='bold')
plt.title('MyGraph',color='green',fontsize=30)
plt.grid(True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[25,16,19,30]
plt.plot(x,y,'o:r')
plt.xlabel('x axis-->',fontsize=20,color='blue',fontweight='bold')
plt.ylabel('y axis-->',fontsize=20,color='red',fontweight='bold')
plt.title('MyGraph',color='green',fontsize=30)
plt.grid(True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
y=[25,16,19,30]
plt.plot(x,y,linestyle="--",linewidth=3,marker='*',ms=20)
plt.xlabel('x axis-->',fontsize=20,color='blue',fontweight='bold')
plt.ylabel('y axis-->',fontsize=20,color='red',fontweight='bold')
plt.title('MyGraph',color='green',fontsize=30)
plt.grid(True,axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
sub=['ps','py','fsd','etc','ci']
s1=[25,22,16,24,23]
s2=[21,17,10,20,14]
s3=[19,15,14,22,21]
plt.plot(sub,s1,linestyle="-",linewidth=3,marker='o',ms=10)
plt.plot(sub,s2,linestyle="-",linewidth=3,marker='o',ms=10)
plt.plot(sub,s3,linestyle="-",linewidth=3,marker='o',ms=10)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,11)
y1=2*x
y2=3*x
plt.subplot(2,1,1) #subplot(row,col,plotno)
plt.plot(x,y1)
plt.subplot(2,1,2)
plt.plot(x,y2)
plt.suptitle("SubPlot")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,11)
y1=2*x
y2=3*x
plt.subplot(1,2,1) #subplot(row,col,plotno)
plt.plot(x,y1,linestyle="-",linewidth=3,marker='o',ms=10)
plt.subplot(1,2,2)
plt.plot(x,y2,linestyle="-",linewidth=3,marker='o',ms=10)
plt.suptitle("SubPlot")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Subplot 1
plt.subplot(3, 2, 1)
x_values = [5, 10, 25, 60, 80]
y_values = [5, 17, 25, 40, 30]
plt.plot(x_values, y_values, color='green', linestyle='dotted', marker='D')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot with Dotted Line and Diamond Marker')

# Subplot 2
plt.subplot(3, 2, 2)
Scores_men = (22, 30, 35, 35, 26)
Scores_women = (25, 32, 30, 35, 29)
groups = ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5']
bar_width = 0.35
bar_positions_men = range(len(groups))
bar_positions_women = [pos + bar_width for pos in bar_positions_men]
plt.bar(bar_positions_men, Scores_men, color='green', width=bar_width,label='Men')
plt.bar(bar_positions_women, Scores_women, color='red', width=bar_width,label='Women')
plt.xlabel('Groups')
plt.ylabel('Scores')
plt.title('Bar Plot of Scores by Group and Gender')
# plt.xticks([pos + bar_width / 2 for pos in bar_positions_men], groups)
# plt.legend(fontsize='small')

# Subplot 3
plt.subplot(3, 2, 3)
car_labels = ['Maruti Suzuki', 'Hyundai', 'Kia', 'Toyota', 'Honda']
popularity = [25, 50, 30, 20, 35]
plt.pie(popularity, labels=car_labels, autopct='%1.1f%%', startangle=90)
plt.title('Popularity of Car Companies')

# Subplot 4
plt.subplot(3, 2, 4)
math_marks = [88, 92, 80, 89, 100, 80, 60, 100, 80, 34]
science_marks = [35, 79, 79, 48, 100, 88, 32, 45, 20, 30]
plt.scatter(range(1, 11), math_marks, marker='o', color='yellow',label='Mathematics')
plt.scatter(range(1, 11), science_marks, marker='*', color='blue',label='Science')
plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Scatter Plot: Mathematics vs Science')
# plt.legend(fontsize='small')

# Subplot 5
plt.subplot(3, 2, 5)
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C', 'C++']
popularity_languages = [20, 100, 25, 30, 45, 50]
plt.barh(languages, popularity_languages, color=['orange', 'green', 'blue','red', 'purple', 'pink'])
plt.xlabel('Popularity')
plt.ylabel('Prog Lang')
plt.title('Popularity of Programming Languages')

# Subplot 6
plt.subplot(3, 2, 6)
data_histogram = [10, 20, 20, 30, 30, 30, 40, 40, 40, 40, 50, 50, 50, 60, 60,70]
plt.hist(data_histogram, color='red', bins=10, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram Chart')
plt.tight_layout(w_pad=10.0) # Increase both vertical and horizontal spacing,add rect parameter for title
plt.show()

# %%
x_values = [5, 10, 25, 60, 80]
y_values = [5, 17, 25, 40, 30]
plt.plot(x_values, y_values, color='green', linestyle='dotted', marker='D')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot with Dotted Line and Diamond Marker')
# Out:
# Text(0.5, 1.0, 'Line Plot with Dotted Line and Diamond Marker')

# %%
import numpy as np
import matplotlib.pyplot as plt
scores= [[31, 12, 19, 53],
[67, 48, 95, 83],
[59, 67, 13, 59],
[62, 29, 99, 88],
[87, 91, 69, 76]]
scores=np.array(scores)
print("1.Find the maximum score")
max=0
for i in scores[:,2]:
    if i>max:
        max=i
print("The maximum score --->",max)
print("2. Find the minimum score of YUVRAJ")
min=scores[2,0] 
for i in scores[2,:]:
    if i<min:
        min=i
print("minimum score of YUVRAJ --->",min)
print("""3.Add an extra column with the sum of all 4 T20 Matches""")
print(" ")
batsman_total=[]
for i in range(0,5):
    add=0
    for j in range(0,4):
        add+=scores[i,j]
    batsman_total.append(add)
batsman_total=np.array(batsman_total).reshape(5,1)
scores=np.concatenate((scores,batsman_total),axis=1)
print("updated array",scores)
# Out:
# 1.Find the maximum score
# The maximum score ---> 99
# 2. Find the minimum score of YUVRAJ
# minimum score of YUVRAJ ---> 13
# 3.Add an extra column with the sum of all 4 T20 Matches
#
# updated array [[ 31  12  19  53 115]
#  [ 67  48  95  83 293]
#  [ 59  67  13  59 198]
#  [ 62  29  99  88 278]
#  [ 87  91  69  76 323]]

# %%
import numpy as np
a1=np.array([1,2,3,4])
a2=np.array([5,6,7,8])
ar=np.concatenate((a1,a2),axis=0)
print(ar.shape)
print(ar)
# Out:
# (8,)
# [1 2 3 4 5 6 7 8]

# %%
import numpy as np
a1=np.array([[1,2],[3,4]])
a2=np.array([[5,6],[7,8]])
ar=np.concatenate((a1,a2),axis=1)
print(ar.shape)
print(ar)
# Out:
# (2, 4)
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
import numpy as np
a1=np.array([[1,2],[3,4]])
a2=np.array([[5,6],[7,8]])
ar=np.concatenate((a1,a2),axis=0)
print(ar.shape)
print(ar)
# Out:
# (4, 2)
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
import numpy as np
a1=np.array([[[1,2],[3,4]]])
a2=np.array([[[5,6],[7,8]]])
ar=np.concatenate((a1,a2),axis=1)
print(ar.shape)
print(ar)
# Out:
# (1, 4, 2)
# [[[1 2]
#   [3 4]
#   [5 6]
#   [7 8]]]

# %%
import numpy as np
a1=np.array([[[1,2],[3,4]]])
a2=np.array([[[5,6],[7,8]]])
ar=np.concatenate((a1,a2),axis=0)
print(ar.shape)
print(ar)
# Out:
# (2, 2, 2)
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
